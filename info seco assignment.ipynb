# %%
import urllib.request

response = urllib.request.urlopen("https://www.example.com")
print(response.read())
# Out:
# b'<!doctype html>\n<html>\n<head>\n    <title>Example Domain</title>\n\n    <meta charset="utf-8" />\n    <meta http-equiv="Content-type" content="text/html; charset=utf-8" />\n    <meta name="viewport" content="width=device-width, initial-scale=1" />\n    <style type="text/css">\n    body {\n        background-color: #f0f0f2;\n        margin: 0;\n        padding: 0;\n        font-family: -apple-system, system-ui, BlinkMacSystemFont, "Segoe UI", "Open Sans", "Helvetica Neue", Helvetica, Arial, sans-serif;\n        \n    }\n    div {\n        width: 600px;\n        margin: 5em auto;\n        padding: 2em;\n        background-color: #fdfdff;\n        border-radius: 0.5em;\n        box-shadow: 2px 3px 7px 2px rgba(0,0,0,0.02);\n    }\n    a:link, a:visited {\n        color: #38488f;\n        text-decoration: none;\n    }\n    @media (max-width: 700px) {\n        div {\n            margin: 0 auto;\n            width: auto;\n        }\n    }\n    </style>    \n</head>\n\n<body>\n<div>\n    <h1>Example Domain</h1>\n    <p>This domain is for use in illustrative examples in documents. You may use this\n    domain in literature without prior coordination or asking for permission.</p>\n    <p><a href="https://www.iana.org/domains/example">More information...</a></p>\n</div>\n</body>\n</html>\n'

# %%
pip install urllib
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement urllib (from versions: none)
# ERROR: No matching distribution found for urllib

# %%
import pandas as pd
import numpy as np
import re
from urllib.parse import urlparse

# %%
data=pd.read_csv('final.csv')

# %%
data
# Out:
#         Unnamed: 0                                                url  \
# 0                0  https://mitsui-jyuku.mixh.jp/uploads/6343fvase...
# 1                1                      http://vbncdfaewoi.ug/az2.exe
# 2                2  http://www.pensiiilfov.ro/index.php?option=com...
# 3                3                               williameworkman.com/
# 4                4  http://archive.salisburyjournal.co.uk/2000/8/3...
# ...            ...                                                ...
# 472869      472869                news.cnet.com/2100-1023-245263.html
# 472870      472870  http://saglikramazan20bgb.net/20gb_hediye_inte...
# 472871      472871  http://www.icci.com.br/index.php?option=com_k2...
# 472872      472872  http://www.niobestudio.com/index.php/component...
# 472873      472873            http://www.acosmotta.com.br/index.php.1
#
#               type  type_encoded
# 0          malware             2
# 1          malware             2
# 2       defacement             1
# 3           benign             0
# 4             spam             4
# ...            ...           ...
# 472869    phishing             3
# 472870     malware             2
# 472871  defacement             1
# 472872  defacement             1
# 472873  defacement             1
#
# [472874 rows x 4 columns]

# %%
# Function to extract URL features
def extract_url_features(url):
    parsed_url = urlparse(url)
    features = {
        'url_length': len(url),
        'num_special_chars': len(re.findall(r'[?&=/_-]', url)),
        'num_subdomains': len(parsed_url.netloc.split('.')) - 2 if url.count('.') > 1 else 0,
        'has_https': int(parsed_url.scheme == 'https'),
        'has_ip_address': int(bool(re.search(r'\b(?:\d{1,3}\.){3}\d{1,3}\b', url))),
        'path_length': len(parsed_url.path),
        'query_length': len(parsed_url.query)
    }
    return features

# Apply URL feature extraction
data_url_features = data['url'].apply(lambda x: pd.Series(extract_url_features(x)))

# One-hot encode 'type'
data_type_encoded = pd.get_dummies(data['type'], prefix='type')

# Normalize 'type_encoded'
data['type_encoded_norm'] = (data['type_encoded'] - data['type_encoded'].min()) / (data['type_encoded'].max() - data['type_encoded'].min())

# Combine all features
data_features = pd.concat([data, data_url_features, data_type_encoded], axis=1)

print(data_features.head())
# Out:
#                                      url        type  type_encoded  \
# 0        http://example.com/test?query=1   malicious             1
# 1    https://sub.domain.com/path/to/page      benign             0
# 2          http://192.168.1.1/index.html  suspicious             2
# 3  https://example.com/test?query=1/ca=/   malicious             1
# 4   http://example.com/test?query=1??=yz   malicious             1
#
#                                       augmented_urls  type_encoded_norm  \
# 0  [https://example.com/test?query=1/ca=/, http:/...                0.5
# 1  [https://sub.domain.com/path/to/pageaa4=z, htt...                0.0
# 2  [https://192.168.1.1/index.html5bc/b, https://...                1.0
# 3                                                NaN                0.5
# 4                                                NaN                0.5
#
#    url_length  num_special_chars  num_subdomains  has_https  has_ip_address  \
# 0          31                  5               0          0               0
# 1          35                  5               1          1               0
# 2          29                  3               2          0               1
# 3          37                  8               0          1               0
# 4          36                  8               0          0               0
#
#    path_length  query_length  type_benign  type_malicious  type_suspicious
# 0            5             7        False            True            False
# 1           13             0         True           False            False
# 2           11             0        False           False             True
# 3            5            12        False            True            False
# 4            5            12        False            True            False

# %%
# Train ML model
model = LogisticRegression(max_iter=100)
model.fit(X_train, y_train)

# Evaluate model
y_pred = model.predict(X_test)
y_prob = model.predict_proba(X_test)[:, 1]

# Metrics
train_accuracy = model.score(X_train, y_train)
test_accuracy = model.score(X_test, y_test)
f1 = f1_score(y_test, y_pred, average='weighted')

print(f"Train Accuracy: {train_accuracy:.4f}")
print(f"Test Accuracy: {test_accuracy:.4f}")
print(f"F1 Score: {f1:.4f}")

# Confusion Matrix
cm = confusion_matrix(y_test, y_pred)
ConfusionMatrixDisplay(cm).plot(cmap='Blues')
plt.title('Confusion Matrix')
plt.show()

# ROC Curve
fpr, tpr, _ = roc_curve(y_test, y_prob, pos_label=1)
roc_auc = auc(fpr, tpr)
plt.plot(fpr, tpr, color='darkorange', label=f'ROC curve (area = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='navy', linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend(loc='lower right')
plt.show()
# Out:
# C:\Users\ha934\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Train Accuracy: 0.8994
# Test Accuracy: 0.8996
# F1 Score: 0.8981

# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix, roc_curve, auc, ConfusionMatrixDisplay, accuracy_score, f1_score
import matplotlib.pyplot as plt
import random


data=pd.read_csv('final.csv')
# Data Augmentation: Generate synthetic URLs
def augment_url(url, n=3):
    augmented_urls = []
    for _ in range(n):
        if 'http' in url:
            new_url = url.replace('http', random.choice(['http', 'https']))
            new_url += ''.join(random.choices('/abcxyz?=12345', k=5))
            augmented_urls.append(new_url)
    return augmented_urls

# Apply augmentation
data['augmented_urls'] = data['url'].apply(lambda x: augment_url(x))
augmented_data = pd.DataFrame([(url, row['type'], row['type_encoded']) for idx, row in data.iterrows() for url in row['augmented_urls']], columns=['url', 'type', 'type_encoded'])
data = pd.concat([data, augmented_data], ignore_index=True)

# TF-IDF features
tfidf_vectorizer = TfidfVectorizer(max_features=500)
tfidf_features = tfidf_vectorizer.fit_transform(data['url']).toarray()
tfidf_df = pd.DataFrame(tfidf_features, columns=[f'tfidf_{i}' for i in range(tfidf_features.shape[1])])

# Combine features
data_features = pd.concat([tfidf_df, data['type_encoded']], axis=1)

# Train-test split
X = data_features.drop(columns=['type_encoded'])
y = data_features['type_encoded']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Train Logistic Regression model
logistic_model = LogisticRegression(max_iter=1000)
logistic_model.fit(X_train, y_train)

# Train Random Forest model
random_forest_model = RandomForestClassifier(random_state=42)
random_forest_model.fit(X_train, y_train)

# Evaluate Logistic Regression model
y_pred_lr = logistic_model.predict(X_test)
y_prob_lr = logistic_model.predict_proba(X_test)[:, 1]

# Evaluate Random Forest model
y_pred_rf = random_forest_model.predict(X_test)
y_prob_rf = random_forest_model.predict_proba(X_test)[:, 1]

# Metrics for Logistic Regression
train_accuracy_lr = logistic_model.score(X_train, y_train)
test_accuracy_lr = logistic_model.score(X_test, y_test)
f1_lr = f1_score(y_test, y_pred_lr, average='weighted')

print("Logistic Regression Metrics:")
print(f"Train Accuracy: {train_accuracy_lr:.4f}")
print(f"Test Accuracy: {test_accuracy_lr:.4f}")
print(f"F1 Score: {f1_lr:.4f}")

# Metrics for Random Forest
train_accuracy_rf = random_forest_model.score(X_train, y_train)
test_accuracy_rf = random_forest_model.score(X_test, y_test)
f1_rf = f1_score(y_test, y_pred_rf, average='weighted')

print("\nRandom Forest Metrics:")
print(f"Train Accuracy: {train_accuracy_rf:.4f}")
print(f"Test Accuracy: {test_accuracy_rf:.4f}")
print(f"F1 Score: {f1_rf:.4f}")

# Confusion Matrix for Random Forest
cm_rf = confusion_matrix(y_test, y_pred_rf)
ConfusionMatrixDisplay(cm_rf).plot(cmap='Blues')
plt.title('Random Forest Confusion Matrix')
plt.show()

# ROC Curve for Random Forest
fpr_rf, tpr_rf, _ = roc_curve(y_test, y_prob_rf, pos_label=1)
roc_auc_rf = auc(fpr_rf, tpr_rf)
plt.plot(fpr_rf, tpr_rf, color='purple', label=f'RF ROC (area = {roc_auc_rf:.2f})')
plt.plot([0, 1], [0, 1], color='navy', linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Random Forest ROC Curve')
plt.legend(loc='lower right')
plt.show()
# Out:
# Logistic Regression Metrics:
# Train Accuracy: 0.9015
# Test Accuracy: 0.9017
# F1 Score: 0.9004
#
# Random Forest Metrics:
# Train Accuracy: 0.9462
# Test Accuracy: 0.9401
# F1 Score: 0.9398

# %%
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, f1_score, confusion_matrix, ConfusionMatrixDisplay, roc_curve, auc
import matplotlib.pyplot as plt

# Load data
data = pd.read_csv('final.csv')

def augment_url(url, n=3):
    augmented_urls = []
    for _ in range(n):
        if 'http' in url:
            new_url = url.replace('http', random.choice(['http', 'https']))
            new_url += ''.join(random.choices('/abcxyz?=12345', k=5))
            augmented_urls.append(new_url)
    return augmented_urls

# Apply augmentation
data['augmented_urls'] = data['url'].apply(lambda x: augment_url(x))
augmented_data = pd.DataFrame([(url, row['type_encoded']) for _, row in data.iterrows() for url in row['augmented_urls']], columns=['url', 'type_encoded'])
data = pd.concat([data, augmented_data], ignore_index=True)

# Generate embeddings
embedding_model = SentenceTransformer('all-MiniLM-L6-v2')
embeddings = embedding_model.encode(data['url'].tolist())

# Normalize embeddings
scaler = StandardScaler()
embeddings = scaler.fit_transform(embeddings)

# Prepare features and labels
data_features = pd.concat([pd.DataFrame(embeddings), data['type_encoded']], axis=1)
X = data_features.drop(columns=['type_encoded']).values
y = data_features['type_encoded'].values

# Train-test split with stratification
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, stratify=y, random_state=42)

# Convert to PyTorch tensors
X_train_tensor = torch.tensor(X_train, dtype=torch.float32)
y_train_tensor = torch.tensor(y_train, dtype=torch.long)
X_test_tensor = torch.tensor(X_test, dtype=torch.float32)
y_test_tensor = torch.tensor(y_test, dtype=torch.long)


# Train-test split with stratification
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)

# Convert to PyTorch tensors
X_train_tensor = torch.tensor(X_train, dtype=torch.float32)
y_train_tensor = torch.tensor(y_train, dtype=torch.long)
X_test_tensor = torch.tensor(X_test, dtype=torch.float32)
y_test_tensor = torch.tensor(y_test, dtype=torch.long)

# Define a simple dense neural network
class DenseClassifier(nn.Module):
    def __init__(self, input_size, hidden_size, output_size):
        super(DenseClassifier, self).__init__()
        self.fc1 = nn.Linear(input_size, hidden_size)
        self.relu = nn.ReLU()
        self.fc2 = nn.Linear(hidden_size, hidden_size)
        self.relu2 = nn.ReLU()
        self.fc3 = nn.Linear(hidden_size, output_size)
        self.softmax = nn.Softmax(dim=1)
    
    def forward(self, x):
        x = self.fc1(x)
        x = self.relu(x)
        x = self.fc2(x)
        x = self.relu2(x)
        x = self.fc3(x)
        return self.softmax(x)

# Model parameters
input_size = X_train.shape[1]
hidden_size = 256
output_size = len(np.unique(y))

# Initialize model, loss, and optimizer
dense_model = DenseClassifier(input_size, hidden_size, output_size)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(dense_model.parameters(), lr=0.005)

# Train the model
num_epochs = 100
for epoch in range(num_epochs):
    dense_model.train()
    optimizer.zero_grad()
    outputs = dense_model(X_train_tensor)
    loss = criterion(outputs, y_train_tensor)
    loss.backward()
    optimizer.step()
    
    with torch.no_grad():
        train_accuracy = accuracy_score(y_train, torch.argmax(dense_model(X_train_tensor), dim=1).numpy())
        test_accuracy = accuracy_score(y_test, torch.argmax(dense_model(X_test_tensor), dim=1).numpy())
    
    print(f"Epoch [{epoch + 1}/{num_epochs}], Loss: {loss.item():.4f}, Train Accuracy: {train_accuracy:.4f}, Test Accuracy: {test_accuracy:.4f}")

# Save model
torch.save(dense_model.state_dict(), 'dense_model.pth')

# Evaluate the model
dense_model.eval()
y_pred_logits = dense_model(X_test_tensor)
y_pred = torch.argmax(y_pred_logits, dim=1).numpy()

# Metrics
test_accuracy_dense = accuracy_score(y_test, y_pred)
f1_dense = f1_score(y_test, y_pred, average='weighted')

print("\nDense Model Metrics:")
print(f"Test Accuracy: {test_accuracy_dense:.4f}")
print(f"F1 Score: {f1_dense:.4f}")

# Confusion Matrix
cm_dense = confusion_matrix(y_test, y_pred)
ConfusionMatrixDisplay(cm_dense).plot(cmap='Blues')
plt.title('Dense Model Confusion Matrix')
plt.show()

# ROC Curve
with torch.no_grad():
    y_prob_dense = torch.nn.functional.softmax(y_pred_logits, dim=1)[:, 1].numpy()
fpr_dense, tpr_dense, _ = roc_curve(y_test, y_prob_dense, pos_label=1)
roc_auc_dense = auc(fpr_dense, tpr_dense)

plt.plot(fpr_dense, tpr_dense, color='blue', label=f'Dense ROC (area = {roc_auc_dense:.2f})')
plt.plot([0, 1], [0, 1], color='navy', linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Dense Model ROC Curve')
plt.legend(loc='lower right')
plt.show()
# Out:
# Epoch [1/100], Loss: 1.6093, Train Accuracy: 0.4327, Test Accuracy: 0.4334
# Epoch [2/100], Loss: 1.5301, Train Accuracy: 0.5718, Test Accuracy: 0.5670
# Epoch [3/100], Loss: 1.3841, Train Accuracy: 0.6910, Test Accuracy: 0.6865
# Epoch [4/100], Loss: 1.2629, Train Accuracy: 0.7240, Test Accuracy: 0.7171
# Epoch [5/100], Loss: 1.1899, Train Accuracy: 0.7347, Test Accuracy: 0.7290
# Epoch [6/100], Loss: 1.1541, Train Accuracy: 0.7764, Test Accuracy: 0.7665
# Epoch [7/100], Loss: 1.1233, Train Accuracy: 0.8237, Test Accuracy: 0.8157
# Epoch [8/100], Loss: 1.0868, Train Accuracy: 0.8193, Test Accuracy: 0.8097
# Epoch [9/100], Loss: 1.0859, Train Accuracy: 0.8244, Test Accuracy: 0.8134
# Epoch [10/100], Loss: 1.0786, Train Accuracy: 0.8316, Test Accuracy: 0.8209
# Epoch [11/100], Loss: 1.0631, Train Accuracy: 0.8541, Test Accuracy: 0.8429
# Epoch [12/100], Loss: 1.0510, Train Accuracy: 0.8539, Test Accuracy: 0.8430
# Epoch [13/100], Loss: 1.0510, Train Accuracy: 0.8595, Test Accuracy: 0.8479
# Epoch [14/100], Loss: 1.0454, Train Accuracy: 0.8693, Test Accuracy: 0.8564
# Epoch [15/100], Loss: 1.0366, Train Accuracy: 0.8740, Test Accuracy: 0.8600
# Epoch [16/100], Loss: 1.0325, Train Accuracy: 0.8742, Test Accuracy: 0.8613
# Epoch [17/100], Loss: 1.0320, Train Accuracy: 0.8775, Test Accuracy: 0.8647
# Epoch [18/100], Loss: 1.0282, Train Accuracy: 0.8814, Test Accuracy: 0.8670
# Epoch [19/100], Loss: 1.0240, Train Accuracy: 0.8817, Test Accuracy: 0.8676
# Epoch [20/100], Loss: 1.0228, Train Accuracy: 0.8831, Test Accuracy: 0.8698
# Epoch [21/100], Loss: 1.0214, Train Accuracy: 0.8870, Test Accuracy: 0.8734
# Epoch [22/100], Loss: 1.0184, Train Accuracy: 0.8883, Test Accuracy: 0.8743
# Epoch [23/100], Loss: 1.0164, Train Accuracy: 0.8903, Test Accuracy: 0.8764
# Epoch [24/100], Loss: 1.0151, Train Accuracy: 0.8917, Test Accuracy: 0.8785
# Epoch [25/100], Loss: 1.0134, Train Accuracy: 0.8950, Test Accuracy: 0.8816
# Epoch [26/100], Loss: 1.0112, Train Accuracy: 0.8963, Test Accuracy: 0.8823
# Epoch [27/100], Loss: 1.0099, Train Accuracy: 0.8969, Test Accuracy: 0.8825
# Epoch [28/100], Loss: 1.0087, Train Accuracy: 0.8975, Test Accuracy: 0.8831
# Epoch [29/100], Loss: 1.0077, Train Accuracy: 0.8988, Test Accuracy: 0.8832
# Epoch [30/100], Loss: 1.0067, Train Accuracy: 0.9005, Test Accuracy: 0.8857
# Epoch [31/100], Loss: 1.0055, Train Accuracy: 0.9010, Test Accuracy: 0.8859
# Epoch [32/100], Loss: 1.0049, Train Accuracy: 0.9013, Test Accuracy: 0.8868
# Epoch [33/100], Loss: 1.0043, Train Accuracy: 0.9025, Test Accuracy: 0.8880
# Epoch [34/100], Loss: 1.0034, Train Accuracy: 0.9032, Test Accuracy: 0.8880
# Epoch [35/100], Loss: 1.0027, Train Accuracy: 0.9035, Test Accuracy: 0.8885
# Epoch [36/100], Loss: 1.0020, Train Accuracy: 0.9042, Test Accuracy: 0.8892
# Epoch [37/100], Loss: 1.0013, Train Accuracy: 0.9043, Test Accuracy: 0.8894
# Epoch [38/100], Loss: 1.0007, Train Accuracy: 0.9059, Test Accuracy: 0.8911
# Epoch [39/100], Loss: 1.0000, Train Accuracy: 0.9060, Test Accuracy: 0.8916
# Epoch [40/100], Loss: 0.9994, Train Accuracy: 0.9068, Test Accuracy: 0.8920
# Epoch [41/100], Loss: 0.9986, Train Accuracy: 0.9074, Test Accuracy: 0.8929
# Epoch [42/100], Loss: 0.9980, Train Accuracy: 0.9082, Test Accuracy: 0.8934
# Epoch [43/100], Loss: 0.9975, Train Accuracy: 0.9086, Test Accuracy: 0.8938
# Epoch [44/100], Loss: 0.9966, Train Accuracy: 0.9091, Test Accuracy: 0.8944
# Epoch [45/100], Loss: 0.9958, Train Accuracy: 0.9093, Test Accuracy: 0.8944
# Epoch [46/100], Loss: 0.9956, Train Accuracy: 0.9088, Test Accuracy: 0.8935
# Epoch [47/100], Loss: 0.9955, Train Accuracy: 0.9101, Test Accuracy: 0.8950
# Epoch [48/100], Loss: 0.9945, Train Accuracy: 0.9104, Test Accuracy: 0.8953
# Epoch [49/100], Loss: 0.9943, Train Accuracy: 0.9108, Test Accuracy: 0.8962
# Epoch [50/100], Loss: 0.9942, Train Accuracy: 0.9116, Test Accuracy: 0.8976
# Epoch [51/100], Loss: 0.9936, Train Accuracy: 0.9117, Test Accuracy: 0.8972
# Epoch [52/100], Loss: 0.9933, Train Accuracy: 0.9121, Test Accuracy: 0.8978
# Epoch [53/100], Loss: 0.9928, Train Accuracy: 0.9126, Test Accuracy: 0.8982
# Epoch [54/100], Loss: 0.9924, Train Accuracy: 0.9128, Test Accuracy: 0.8982
# Epoch [55/100], Loss: 0.9922, Train Accuracy: 0.9133, Test Accuracy: 0.8987
# Epoch [56/100], Loss: 0.9920, Train Accuracy: 0.9135, Test Accuracy: 0.8984
# Epoch [57/100], Loss: 0.9915, Train Accuracy: 0.9133, Test Accuracy: 0.8981
# Epoch [58/100], Loss: 0.9916, Train Accuracy: 0.9133, Test Accuracy: 0.8977
# Epoch [59/100], Loss: 0.9916, Train Accuracy: 0.9140, Test Accuracy: 0.8993
# Epoch [60/100], Loss: 0.9912, Train Accuracy: 0.9137, Test Accuracy: 0.8985
# Epoch [61/100], Loss: 0.9910, Train Accuracy: 0.9140, Test Accuracy: 0.8985
# Epoch [62/100], Loss: 0.9907, Train Accuracy: 0.9144, Test Accuracy: 0.8993
# Epoch [63/100], Loss: 0.9903, Train Accuracy: 0.9144, Test Accuracy: 0.8992
# Epoch [64/100], Loss: 0.9903, Train Accuracy: 0.9146, Test Accuracy: 0.8998
# Epoch [65/100], Loss: 0.9900, Train Accuracy: 0.9150, Test Accuracy: 0.8999
# Epoch [66/100], Loss: 0.9901, Train Accuracy: 0.9142, Test Accuracy: 0.8991
# Epoch [67/100], Loss: 0.9907, Train Accuracy: 0.9155, Test Accuracy: 0.8999
# Epoch [68/100], Loss: 0.9898, Train Accuracy: 0.9152, Test Accuracy: 0.9004
# Epoch [69/100], Loss: 0.9899, Train Accuracy: 0.9153, Test Accuracy: 0.9005
# Epoch [70/100], Loss: 0.9898, Train Accuracy: 0.9156, Test Accuracy: 0.8999
# Epoch [71/100], Loss: 0.9896, Train Accuracy: 0.9158, Test Accuracy: 0.9000
# Epoch [72/100], Loss: 0.9894, Train Accuracy: 0.9159, Test Accuracy: 0.9005
# Epoch [73/100], Loss: 0.9893, Train Accuracy: 0.9160, Test Accuracy: 0.9007
# Epoch [74/100], Loss: 0.9892, Train Accuracy: 0.9162, Test Accuracy: 0.9007
# Epoch [75/100], Loss: 0.9890, Train Accuracy: 0.9164, Test Accuracy: 0.9011
# Epoch [76/100], Loss: 0.9888, Train Accuracy: 0.9165, Test Accuracy: 0.9009
# Epoch [77/100], Loss: 0.9886, Train Accuracy: 0.9166, Test Accuracy: 0.9010
# Epoch [78/100], Loss: 0.9884, Train Accuracy: 0.9168, Test Accuracy: 0.9012
# Epoch [79/100], Loss: 0.9882, Train Accuracy: 0.9171, Test Accuracy: 0.9018
# Epoch [80/100], Loss: 0.9881, Train Accuracy: 0.9171, Test Accuracy: 0.9020
# Epoch [81/100], Loss: 0.9880, Train Accuracy: 0.9172, Test Accuracy: 0.9022
# Epoch [82/100], Loss: 0.9878, Train Accuracy: 0.9174, Test Accuracy: 0.9022
# Epoch [83/100], Loss: 0.9877, Train Accuracy: 0.9177, Test Accuracy: 0.9020
# Epoch [84/100], Loss: 0.9875, Train Accuracy: 0.9179, Test Accuracy: 0.9021
# Epoch [85/100], Loss: 0.9873, Train Accuracy: 0.9178, Test Accuracy: 0.9024
# Epoch [86/100], Loss: 0.9873, Train Accuracy: 0.9181, Test Accuracy: 0.9023
# Epoch [87/100], Loss: 0.9871, Train Accuracy: 0.9182, Test Accuracy: 0.9028
# Epoch [88/100], Loss: 0.9870, Train Accuracy: 0.9182, Test Accuracy: 0.9029
# Epoch [89/100], Loss: 0.9869, Train Accuracy: 0.9182, Test Accuracy: 0.9023
# Epoch [90/100], Loss: 0.9868, Train Accuracy: 0.9184, Test Accuracy: 0.9027
# Epoch [91/100], Loss: 0.9866, Train Accuracy: 0.9185, Test Accuracy: 0.9031
# Epoch [92/100], Loss: 0.9865, Train Accuracy: 0.9187, Test Accuracy: 0.9028
# Epoch [93/100], Loss: 0.9863, Train Accuracy: 0.9188, Test Accuracy: 0.9030
# Epoch [94/100], Loss: 0.9862, Train Accuracy: 0.9188, Test Accuracy: 0.9031
# Epoch [95/100], Loss: 0.9861, Train Accuracy: 0.9189, Test Accuracy: 0.9031
# Epoch [96/100], Loss: 0.9861, Train Accuracy: 0.9189, Test Accuracy: 0.9036
# Epoch [97/100], Loss: 0.9860, Train Accuracy: 0.9190, Test Accuracy: 0.9035
# Epoch [98/100], Loss: 0.9859, Train Accuracy: 0.9192, Test Accuracy: 0.9032
# Epoch [99/100], Loss: 0.9858, Train Accuracy: 0.9192, Test Accuracy: 0.9036
# Epoch [100/100], Loss: 0.9858, Train Accuracy: 0.9192, Test Accuracy: 0.9037
#
# Dense Model Metrics:
# Test Accuracy: 0.9037
# F1 Score: 0.9038
